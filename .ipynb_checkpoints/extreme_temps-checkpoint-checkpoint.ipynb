# %% [markdown]
# This exercise was from a Coursera course on Matplotlib. The goal was to plot the extreme high and low temperatures over the span of 2005-2014 from a number of Detroit-area weather stations, and then identify and plot the 2015 temperatures that were outside of the range of temperatures for the previous 10 years. This also included a fun semi-interactive map visual.

# %%
import folium
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# %%
# weather station location file

df = pd.read_csv('BinSize_d400.csv')
station_locations_by_hash = df[df['hash'] == 'fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89']

# get longitude and latitude to plot
lons = station_locations_by_hash['LONGITUDE'].tolist()
lats = station_locations_by_hash['LATITUDE'].tolist()

# plot on a folium map
my_map = folium.Map(location = [lats[0], lons[0]], height = 500,  zoom_start = 9)
for lat, lon in zip(lats, lons):
    folium.Marker([lat, lon]).add_to(my_map)

# render map
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c399b2ae038fdbf3504ec39ca450e4aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c399b2ae038fdbf3504ec39ca450e4aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c399b2ae038fdbf3504ec39ca450e4aa = L.map(
#                 &quot;map_c399b2ae038fdbf3504ec39ca450e4aa&quot;,
#                 {
#                     center: [41.9164, -84.0158],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9591020c5a31a8f1fa312822e9925811 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9591020c5a31a8f1fa312822e9925811.addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_7d33fad0034e8d43e91716f9b1932ede = L.marker(
#                 [41.9164, -84.0158],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_aaa6cf52956ccfe138e5531ace5a7225 = L.marker(
#                 [42.2875, -83.7611],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_ccd7a9590a0ad2fd04f7363bd8929d87 = L.marker(
#                 [42.2417, -83.6933],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_8d9fdb99653d9d56acf2d7ac75816db6 = L.marker(
#                 [42.2947, -83.7108],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_bbe806d878103f3a8e061330bc70c633 = L.marker(
#                 [41.84, -83.8608],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_37f8a373986e70014b78bbe2718f4ccf = L.marker(
#                 [42.0636, -83.4358],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_d1548bb3ebaf5f24448420971e435542 = L.marker(
#                 [42.3264, -84.0133],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_c8072be0563d1cb03771771f24085a8f = L.marker(
#                 [41.9553, -83.6489],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_2bd8c14fefd4ec921db8927c7cd9795d = L.marker(
#                 [42.4344, -83.9858],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_43240b9d9d4d3cc467bd6076f8d18304 = L.marker(
#                 [42.1508, -84.0236],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_502e3bff9ba718dc2a46dba890a00afb = L.marker(
#                 [42.0664, -83.6186],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_af9ee88d1a00d6be0e040cbb748bf3d5 = L.marker(
#                 [42.0811, -83.6769],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_a0d64c4b639e5d33876efc3d3f449512 = L.marker(
#                 [41.9069, -83.4158],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_89aaa3a35e149b83c805ffa6a5492998 = L.marker(
#                 [41.9497, -83.28],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_82902926aba864ab1f8ba2ffb7a5503c = L.marker(
#                 [42.1611, -83.7819],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_859ee70129ca8c07170393ebddb7e250 = L.marker(
#                 [42.1236, -83.82],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_13ed7c6c3ac795277541c6366410cd93 = L.marker(
#                 [41.8069, -83.5831],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_27863a951b0571361f7a477b9642e341 = L.marker(
#                 [42.0028, -83.9336],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_8c577216b2986de63d366c9c43825c99 = L.marker(
#                 [42.0283, -84.1108],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_f88cd2313a8c7f12cb95b729e72a199c = L.marker(
#                 [42.4356, -83.7831],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_71022fc8bc9979a5f40d0ea37e0df776 = L.marker(
#                 [41.5631, -83.4764],
#                 {}
#             ).addTo(map_c399b2ae038fdbf3504ec39ca450e4aa);
#
#
#             var marker_9

# %%
# temperature data file
dft = pd.read_csv('fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv')
pd.set_option('display.max_rows',100)

# %%
# convert all date values to datetime64 format for consistency
dft['date_val'] = dft['Date'].astype('datetime64[ns]')

# %%
dft = dft.sort_values('date_val')

# %%
# We will later group these by calendar day across a span of years, so this gives us the calendar date (without year)
dft['calendar_day'] = dft['date_val'].dt.strftime('%m-%d')

# %%
# temp values were in tenths of a degree C, so they need to be divided by 10 to render in degrees C. Also creating columns for month, day, and year, which can come in handy for filtering or averaging

dft['Data_Value'] = dft['Data_Value']/10
dft['month'] = dft['date_val'].dt.month
dft['day'] = dft['date_val'].dt.day
dft['year'] = dft['date_val'].dt.year

# %%
# filter out leap days to simplify the process
filt_feb29 = dft['date_val'].dt.month.eq(2) & dft['date_val'].dt.day.eq(29)
dft = dft.loc[~filt_feb29]

# %%
filtmax = (dft['Element'] == 'TMAX')

# %%
#filter dataframe of just the max temps
dft_max = dft.loc[filtmax]

# %%
filtmin = (dft['Element'] == 'TMIN')

# %%
#filter dataframe to just the min temps
dft_min = dft.loc[filtmin]

# %%
#create one date series for 2005-2014 and another for just 2015
filt2015min = dft_min['date_val'].dt.year.eq(2015)
filt2015max = dft_max['date_val'].dt.year.eq(2015)
lows_2015 = dft_min.loc[filt2015min]
lows_pre2015 = dft_min.loc[~filt2015min]
highs_2015 = dft_max.loc[filt2015max]
highs_pre2015 = dft_max.loc[~filt2015max]

# %%
lows_pre2015.columns
# Out:
# Index(['ID', 'Date', 'Element', 'Data_Value', 'date_val', 'calendar_day',
#        'month', 'day', 'year'],
#       dtype='object')

# %%
# set index to date_val 
lows_pre2015.set_index(['date_val'], inplace = True)
lows_2015.set_index(['date_val'], inplace = True)
highs_2015.set_index(['date_val'], inplace = True)
highs_pre2015.set_index(['date_val'], inplace = True)

# %%
highs_pre2015
# Out:
#                      ID        Date Element  Data_Value calendar_day  month  \
# date_val
# 2005-01-01  USC00207320    1/1/2005    TMAX        15.0        01-01      1
# 2005-01-01  USW00014833    1/1/2005    TMAX         3.3        01-01      1
# 2005-01-01  USW00004848    1/1/2005    TMAX        13.3        01-01      1
# 2005-01-01  USC00205563    1/1/2005    TMAX         2.8        01-01      1
# 2005-01-01  USW00014853    1/1/2005    TMAX         5.6        01-01      1
# ...                 ...         ...     ...         ...          ...    ...
# 2014-12-31  USC00200032  12/31/2014    TMAX        -5.6        12-31     12
# 2014-12-31  USC00201502  12/31/2014    TMAX        -5.6        12-31     12
# 2014-12-31  USC00200228  12/31/2014    TMAX        -3.9        12-31     12
# 2014-12-31  USC00205563  12/31/2014    TMAX        -2.8        12-31     12
# 2014-12-31  USC00205822  12/31/2014    TMAX        -2.8        12-31     12
#
#             day  year
# date_val
# 2005-01-01    1  2005
# 2005-01-01    1  2005
# 2005-01-01    1  2005
# 2005-01-01    1  2005
# 2005-01-01    1  2005
# ...         ...   ...
# 2014-12-31   31  2014
# 2014-12-31   31  2014
# 2014-12-31   31  2014
# 2014-12-31   31  2014
# 2014-12-31   31  2014
#
# [76100 rows x 8 columns]

# %%
highs_pre2015.loc['2007']
# Out:
#                      ID        Date Element  Data_Value calendar_day  month  \
# date_val
# 2007-01-01  USW00004848    1/1/2007    TMAX        10.6        01-01      1
# 2007-01-01  USC00207312    1/1/2007    TMAX        10.6        01-01      1
# 2007-01-01  USC00205451    1/1/2007    TMAX        10.6        01-01      1
# 2007-01-01  USW00094889    1/1/2007    TMAX         8.3        01-01      1
# 2007-01-01  USC00200228    1/1/2007    TMAX        10.6        01-01      1
# ...                 ...         ...     ...         ...          ...    ...
# 2007-12-31  USC00205451  12/31/2007    TMAX        -1.7        12-31     12
# 2007-12-31  USC00200228  12/31/2007    TMAX        -1.7        12-31     12
# 2007-12-31  USC00208202  12/31/2007    TMAX        -1.7        12-31     12
# 2007-12-31  USC00207308  12/31/2007    TMAX        -1.1        12-31     12
# 2007-12-31  USW00004848  12/31/2007    TMAX         3.9        12-31     12
#
#             day  year
# date_val
# 2007-01-01    1  2007
# 2007-01-01    1  2007
# 2007-01-01    1  2007
# 2007-01-01    1  2007
# 2007-01-01    1  2007
# ...         ...   ...
# 2007-12-31   31  2007
# 2007-12-31   31  2007
# 2007-12-31   31  2007
# 2007-12-31   31  2007
# 2007-12-31   31  2007
#
# [7208 rows x 8 columns]

# %%
#identify the high for each grouped calendar day 2005-2014
rec_highs_pre2015 = highs_pre2015.groupby('calendar_day')['Data_Value'].max()

# %%
#identify the low for each grouped calendar day 2005-2014
rec_lows_pre2015 = lows_pre2015.groupby('calendar_day')['Data_Value'].min()

# %%
#identify the high for each grouped calendar day 2015
rec_highs_2015 = highs_2015.groupby('calendar_day')['Data_Value'].max()

# %%
#identify the low for each grouped calendar day 2015
rec_lows_2015 = lows_2015.groupby('calendar_day')['Data_Value'].min()

# %%
rec_lows_2015
# Out:
# calendar_day
# 01-01   -13.3
# 01-02   -12.2
# 01-03    -6.7
# 01-04    -8.8
# 01-05   -15.5
#          ...
# 12-27    -0.6
# 12-28    -3.9
# 12-29    -3.9
# 12-30    -2.2
# 12-31    -5.6
# Name: Data_Value, Length: 365, dtype: float64

# %%
#merging the 4 data series into a single DataFrame, date formatting for the visualization
merged_temp_records = pd.merge(rec_highs_pre2015,rec_lows_pre2015, how = 'left', on = 'calendar_day')

# %%
merged_temp_records = pd.merge(merged_temp_records,rec_highs_2015, how = 'left', on = 'calendar_day')

# %%
merged_temp_records.rename(columns={'Data_Value_x': 'highT_pre2015', 'Data_Value_y': 'lowT_pre2015', 'Data_Value':'highT_2015'}, inplace = True)

# %%
merged_temp_records['lowT_2015'] = rec_lows_2015

# %%
merged_temp_records['date'] = pd.to_datetime(merged_temp_records.index, format = '%m-%d')

# %%
merged_temp_records['month'] = merged_temp_records['date'].dt.strftime('%b')

# %%
filtlow = (merged_temp_records['lowT_2015'] < merged_temp_records['lowT_pre2015'])
filthigh = (merged_temp_records['highT_2015'] > merged_temp_records['highT_pre2015'])
low2015 = merged_temp_records.loc[filtlow]
high2015 = merged_temp_records.loc[filthigh]
# Out:
# (32, 37)

# %%
plt.plot(merged_temp_records['date'], merged_temp_records['lowT_pre2015'], color = 'blue', label = 'Lowest T 2005-14')
plt.plot(merged_temp_records['date'], merged_temp_records['highT_pre2015'], color = 'red', label = 'Highest T 2005-14')
plt.fill_between(merged_temp_records['date'], merged_temp_records['lowT_pre2015'], merged_temp_records['highT_pre2015'], color='yellow')
plt.scatter(high2015['date'], high2015['highT_2015'], color = 'green', label = 'Recordbreaking High 2015')
plt.scatter(low2015['date'], low2015['lowT_2015'], color = 'purple', label = 'Recordbreaking Low 2015')
plt.xlabel('Time of Year')
plt.ylabel('Temperature (C)')
plt.title('Comparison of Record Temperature')
date_format = mdates.DateFormatter('%b %d')
plt.gca().xaxis.set_major_formatter(date_format)
plt.legend()

# %%
merged_temp_records.head()
# Out:
#               highT_pre2015  lowT_pre2015  highT_2015  lowT_2015       date  \
# calendar_day
# 01-01                  15.6         -16.0         1.1      -13.3 1900-01-01
# 01-02                  13.9         -26.7         3.9      -12.2 1900-01-02
# 01-03                  13.3         -26.7         3.9       -6.7 1900-01-03
# 01-04                  10.6         -26.1         4.4       -8.8 1900-01-04
# 01-05                  12.8         -15.0         2.8      -15.5 1900-01-05
# 01-06                  18.9         -26.6         3.3      -18.2 1900-01-06
# 01-07                  21.7         -30.6        -6.7      -18.2 1900-01-07
# 01-08                  19.4         -29.4        -8.2      -21.1 1900-01-08
# 01-09                  17.8         -27.8        -6.6      -20.6 1900-01-09
# 01-10                  10.0         -25.6        -7.1      -20.6 1900-01-10
# 01-11                  15.6         -18.3         0.6      -20.0 1900-01-11
# 01-12                  16.1         -19.3         0.6      -11.7 1900-01-12
# 01-13                  16.7         -25.0         0.0      -21.6 1900-01-13
# 01-14                  15.0         -26.6        -5.6      -24.4 1900-01-14
# 01-15                   6.7         -27.2        -0.5      -20.0 1900-01-15
# 01-16                   9.4         -29.4         0.6      -16.7 1900-01-16
# 01-17                  13.3         -29.4         7.8      -11.7 1900-01-17
# 01-18                  12.2         -28.9         8.3      -10.0 1900-01-18
# 01-19                  10.6         -30.0         6.7       -1.7 1900-01-19
# 01-20                  13.3         -23.9         3.9       -3.3 1900-01-20
# 01-21                  13.3         -26.0         2.2       -6.1 1900-01-21
# 01-22                  11.7         -27.7        -0.5       -6.7 1900-01-22
# 01-23                  12.8         -25.0         1.1      -10.0 1900-01-23
# 01-24                  11.7         -26.7         4.4       -6.1 1900-01-24
# 01-25                  10.0         -24.3         3.3       -8.8 1900-01-25
# 01-26                   8.9         -23.8         2.8      -15.0 1900-01-26
# 01-27                   7.8         -23.9        -0.5      -16.1 1900-01-27
# 01-28                  12.2         -29.4         0.6      -17.2 1900-01-28
# 01-29                  17.8         -27.8         3.9      -16.7 1900-01-29
# 01-30                  18.3         -23.3         2.8      -14.3 1900-01-30
# 01-31                  14.4         -19.4         2.8      -15.6 1900-01-31
# 02-01                  15.0         -21.1         3.9      -12.2 1900-02-01
# 02-02                  10.6         -21.1        -2.2      -19.3 1900-02-02
# 02-03                   8.9         -23.2        -2.1      -23.8 1900-02-03
# 02-04                  11.7         -26.1         1.1      -21.1 1900-02-04
# 02-05                  12.2         -28.2         1.1      -27.7 1900-02-05
# 02-06                  11.7         -26.1         0.0      -25.0 1900-02-06
# 02-07                  11.7         -23.3         5.6      -12.2 1900-02-07
# 02-08                  12.8         -22.8         8.3       -5.6 1900-02-08
# 02-09                   7.8         -21.0         8.3      -11.6 1900-02-09
# 02-10                  16.1         -25.6         0.0      -17.1 1900-02-10
# 02-11                  16.1         -25.5         3.3      -15.0 1900-02-11
# 02-12                  19.4         -28.8         1.1      -21.1 1900-02-12
# 02-13                   9.4         -27.2        -3.2      -26.6 1900-02-13
# 02-14                  10.6         -21.7        -2.7      -23.9 1900-02-14
# 02-15                  11.7         -25.6        -3.9      -26.0 1900-02-15
# 02-16                  14.4         -22.2       -12.1      -29.4 1900-02-16
# 02-17                  15.6         -24.3        -5.5      -27.2 1900-02-17
# 02-18                  14.4         -22.2        -3.9      -21.7 1900-02-18
# 02-19                  12.8         -18.8        -5.6      -26.0 1900-02-19
# 02-20                  10.6         -17.8        -8.8      -34.3 1900-02-20
# 02-21                  10.0         -17.8        -1.0      -32.2 1900-02-21
# 02-22                  10.6         -17.2         0.0      -16.0 1900-02-22
# 02-23                  12.2         -22.8         2.2      -26.7 1900-02-23
# 02-24                  11.1         -21.1        -3.8      -27.2 1900-02-24
# 02-25                   9.4         -17.2        -3.8      -21.7 1900-02-25
# 02-26                  11.1         -20.0        -3.3      -21.6 1900-02-26
# 02-27                  12.2         -23.8        -5.0      -28.8 1900-02-27
# 02-28                  11.7         -27.1        -3.9      -27.2 1900-02-28
# 03-01                  11.7         -26.7        -1.7      -24.4 1900-03-01
# 03-02                  15.6         -18.2         1.7      -14.4 1900-03-02
# 03-03                  16.1         -24.4         4.4      -12.2 1900-03-03
# 03-04                  15.6         -23.9         3.3      -12.2 1900-03-04
# 03-05                  15.6         -18.9         3.9      -22.1 1900-03-05
# 03-06                  20.6         -17.8        -3.9      -25.5 1900-03-06
# 03-07                  21.1         -17.8         7.8      -22.2 1900-03-07
# 03-08                  20.0         -16.7         8.3      -10.6 1900-03-08
# 03-09                  18.9         -14.4         9.4       -8.9 1900-03-09
# 03-10                  18.9         -15.6        10.0       -6.7 1900-03-10
# 03-11                  20.0         -12.2        13.3       -3.8 1900-03-11
# 03-12                  20.6         -14.4        12.8       -6.7 1900-03-12
# 03-13                  22.8         -22.2        15.0       -5.0 1900-03-13
# 03-14                  26.7         -20.6        12.8       -3.3 1900-03-14
# 03-15                  26.7         -10.6        13.9       -2.2 1900-03-15
# 03-16                  26.1         -13.9        20.6       -6.7 1900-03-16
# 03-17                  26.1         -17.8        19.4       -5.5 1900-03-17
# 03-18                  25.0         -16.1        11.7       -7.8 1900-03-18
# 03-19                  26.7         -10.0        10.6       -6.7 1900-03-19
# 03-20                  30.0         -10.6        11.7       -5.0 1900-03-20
# 03-21                  30.6         -13.3        12.8       -2.2 1900-03-21
# 03-22                  31.7         -12.2        11.7       -7.2 1900-03-22
# 03-23                  30.6         -13.3        11.1       -9.4 1900-03-23
# 03-24                  28.3         -15.0         7.2      -11.1 1900-03-24
# 03-25                  23.3         -13.9        12.8      -11.1 1900-03-25
# 03-26                  27.2         -15.6        11.1       -2.8 1900-03-26
# 03-27                  26.7         -15.6        12.8      -11.7 1900-03-27
# 03-28                  27.2         -10.6         4.4      -12.2 1900-03-28
# 03-29                  22.2         -10.0         8.9      -11.1 1900-03-29
# 03-30                  23.9          -9.4        16.7      -12.2 1900-03-30
# 03-31                  23.3          -8.3        15.0       -6.7 1900-03-31
# 04-01                  27.2          -8.3        20.6       -4.3 1900-04-01
# 04-02                  27.8          -7.8        19.4       -3.3 1900-04-02
# 04-03                  27.2          -8.9        17.2       -0.5 1900-04-03
# 04-04                  25.6          -8.3        15.6       -5.6 1900-04-04
# 04-05                  25.6          -7.2        19.4       -5.6 1900-04-05
# 04-06                  28.3          -9.4        18.3       -2.2 1900-04-06
# 04-07                  27.8          -8.3        17.2       -1.7 1900-04-07
# 04-08                  22.8          -8.9        16.7        1.1 1900-04-08
# 04-09                  21.7          -6.7        21.1        1.7 1900-04-09
# 04-10                  30.0          -8.3        21.7        1.7 1900-04-10
#
#              month
# calendar_day
# 01-01          Jan
# 01-02          Jan
# 01-03          Jan
# 01-04          Jan
# 01-05          Jan
# 01-06          Jan
# 01-07          Jan
# 01-08          Jan
# 01-09          Jan
# 01-10          Jan
# 01-11          Jan
# 01-12          Jan
# 01-13          Jan
# 01-14          Jan
# 01-15          Jan
# 01-16          Jan
# 01-17          Jan
# 01-18          Jan
# 01-19          Jan
# 01-20          Jan
# 01-21          Jan
# 01-22          Jan
# 01-23          Jan
# 01-24          Jan
# 01-25          Jan
# 01-26          Jan
# 01-27          Jan
# 01-28          Jan
# 01-29          Jan
# 01-30          Jan
# 01-31          Jan
# 02-01          Feb
# 02-02          Feb
# 02-03          Feb
# 02-04          Feb
# 02-05          Feb
# 02-06          Feb
# 02-07          Feb
# 02-08          Feb
# 02-09          Feb
# 02-10          Feb
# 02-11          Feb
# 02-12          Feb
# 02-13          Feb
# 02-14          Feb
# 02-15          Feb
# 02-16          Feb
# 02-17          Feb
# 02-18          Feb
# 02-19          Feb
# 02-20          Feb
# 02-21          Feb
# 02-22          Feb
# 02-23          Feb
# 02-24          Feb
# 02-25          Feb
# 02-26          Feb
# 02-27          Feb
# 02-28          Feb
# 03-01          Mar
# 03-02          Mar
# 03-03          Mar
# 03-04          Mar
# 03-05          Mar
# 03-06          Mar
# 03-07          Mar
# 03-08          Mar
# 03-09          Mar
# 03-10          Mar
# 03-11          Mar
# 03-12          Mar
# 03-13          Mar
# 03-14          Mar
# 03-15          Mar
# 03-16          Mar
# 03-17          Mar
# 03-18          Mar
# 03-19          Mar
# 03-20          Mar
# 03-21          Mar
# 03-22          Mar
# 03-23          Mar
# 03-24          Mar
# 03-25          Mar
# 03-26          Mar
# 03-27          Mar
# 03-28          Mar
# 03-29          Mar
# 03-30          Mar
# 03-31          Mar
# 04-01          Apr
# 04-02          Apr
# 04-03          Apr
# 04-04          Apr
# 04-05          Apr
# 04-06          Apr
# 04-07          Apr
# 04-08          Apr
# 04-09          Apr
# 04-10          Apr
